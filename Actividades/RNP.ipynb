# %% [markdown]
# Actividad 5: Uso de software para búsqueda. Nombre: Yessica Sughey Cantú Morón. Matricula: 1900009. Hora: LMV-N4

# %%
#LIBRERIAS
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.15.0

# %%
#DATOS DEL MNIST
keras.datasets.mnist.load_data(path="mnist.npz")
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
assert x_train.shape == (60000, 28, 28)
assert x_test.shape == (10000, 28, 28)
assert y_train.shape == (60000,)
assert y_test.shape == (10000,)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
#ASIGNACIÓN DE NOMBRES 0-9
class_names = ['Cero', 'Uno', 'Dos', 'Tres', 'Cuatro', 'Cinco', 'Seis', 'Siete','Ocho', 'Nueve']

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
len(y_train)
# Out:
# 60000

# %%
y_train
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
len(y_test)
# Out:
# 10000

# %%
plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(x_train[i], cmap=plt.cm.binary)
  plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
#ENTRENAMIENTO
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2646 - accuracy: 0.9246
# Epoch 2/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1171 - accuracy: 0.9658
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0810 - accuracy: 0.9754
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0597 - accuracy: 0.9821
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0482 - accuracy: 0.9848
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0363 - accuracy: 0.9888
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0289 - accuracy: 0.9913
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0236 - accuracy: 0.9925
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0189 - accuracy: 0.9942
# Epoch 10/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0158 - accuracy: 0.9951

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.0870 - accuracy: 0.9771 - 1s/epoch - 3ms/step
#
# Test accuracy: 0.9771000146865845

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %%
#PREDICCIÓN 1
predictions[0]
# Out:
# array([2.6218864e-08, 8.3464415e-13, 7.1503678e-07, 2.5665360e-05,
#        5.8796336e-11, 5.3480433e-09, 2.0618511e-12, 9.9993557e-01,
#        1.8394309e-06, 3.6241589e-05], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 7

# %%
y_test[0]
# Out:
# 7

# %%
#PREDICCIÓN 2
predictions[5]
# Out:
# array([7.8312370e-11, 9.9997097e-01, 6.5020949e-09, 2.3954858e-08,
#        8.4363927e-07, 6.3479062e-11, 9.2596147e-10, 2.7726088e-05,
#        3.7570172e-07, 7.1446693e-09], dtype=float32)

# %%
np.argmax(predictions[5])
# Out:
# 1

# %%
y_test[5]
# Out:
# 1

# %%
#PREDICCIÓN 3
predictions[9]
# Out:
# array([3.1141825e-15, 1.4863990e-18, 4.8586328e-14, 6.0221400e-10,
#        9.5596763e-05, 2.4857072e-13, 1.4120533e-18, 1.5100899e-07,
#        6.4861190e-08, 9.9990410e-01], dtype=float32)

# %%
np.argmax(predictions[9])
# Out:
# 9

# %%
y_test[9]
# Out:
# 9

# %%
#PREDICCIÓN 4
predictions[24]
# Out:
# array([4.3814580e-11, 1.8611092e-11, 1.9432724e-09, 1.5363474e-11,
#        9.9998921e-01, 9.0411859e-08, 2.2222644e-09, 4.5235595e-07,
#        1.8504781e-09, 1.0120232e-05], dtype=float32)

# %%
np.argmax(predictions[24])
# Out:
# 4

# %%
y_test[24]
# Out:
# 4

# %%
#PREDICCIÓN 5
predictions[3458]
# Out:
# array([9.9998528e-01, 1.5033047e-15, 1.3473040e-08, 9.3296933e-12,
#        2.2329456e-09, 1.8565206e-08, 6.7505212e-06, 8.2654585e-09,
#        2.9322863e-13, 7.8417715e-06], dtype=float32)

# %%
np.argmax(predictions[3458])
# Out:
# 0

# %%
y_test[3458]
# Out:
# 0

# %%
#GRÁFICAS 10 CLASES
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
#GRÁFICAAS PREDICCIONES 1-5
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], y_test, x_test)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  y_test)
plt.show()

# %%
i = 5
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], y_test, x_test)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  y_test)
plt.show()

# %%
i = 9
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], y_test, x_test)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  y_test)
plt.show()

# %%
i = 24
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], y_test, x_test)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  y_test)
plt.show()

# %%
i = 3458
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], y_test, x_test)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  y_test)
plt.show()

# %%
#GRAFICAR IMAGENES
num_rows = 6
num_cols = 4
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], y_test)
plt.tight_layout()
plt.show()

# %%
#MODELO ENTRENADO
img = x_test[1]
print(img.shape)
# Out:
# (28, 28)

# %%
img = (np.expand_dims(img,0))
print(img.shape)
# Out:
# (1, 28, 28)

# %%
predictions_single = model.predict(img)
print(predictions_single)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# [[3.5319887e-12 2.8607926e-07 9.9999964e-01 1.8771173e-08 1.4669583e-20
#   3.6211305e-12 1.8680316e-11 8.0543377e-17 2.0703146e-08 4.7875382e-16]]

# %%
plot_value_array(1, predictions_single[0], y_test)
_ = plt.xticks(range(10), class_names, rotation=45)

# %%
np.argmax(predictions_single[0])
# Out:
# 2
